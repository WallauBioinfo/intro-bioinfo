# %% [markdown]
# # Alinhamento concatenados e múltiplos marcadores - Filogenômica

# %% [markdown]
# ## Objetivos

# %% [markdown]
# 1. Introdução aos Conceitos Fundamentais: Fornecer uma compreensão básica do que é pangenoma, genoma core, genoma acessório e sua importância na compreensão da diversidade genômica dentro de uma espécie ou grupo taxonômico.
#
# 2. Compreensão das Ferramentas e Métodos: Apresentar as ferramentas e técnicas utilizadas na análise de pangenomas, como alinhamento de sequências, chamada de variantes e análise comparativa de genomas.
#
# 3. Análise de Dados Genômicos: Demonstrar como realizar análises de pangenoma utilizando dados genômicos reais, incluindo interpretação de resultados e identificação de padrões genômicos.
#
# 4. Aplicações e Relevância: Discutir as aplicações práticas da pangenômica em áreas como biologia evolutiva, medicina, agronomia e conservação de espécies, destacando a importância de compreender a diversidade genética dentro de populações e espécies.
#
# 5. Desenvolvimento de Habilidades Práticas: Oferecer aos alunos a oportunidade de aplicar as ferramentas e técnicas aprendidas em exercícios práticos, promovendo o desenvolvimento de habilidades em bioinformática e análise de dados genômicos.
#
# 6. Discussão de Estudos de Caso: Explorar estudos de caso recentes que utilizam abordagens de pangenômica para responder a perguntas biológicas específicas, incentivando a reflexão crítica sobre os métodos e resultados apresentados.
#
# 7. Estímulo ao Pensamento Criativo: Encorajar os alunos a pensar de forma criativa sobre novas maneiras de aplicar técnicas de pangenômica em suas próprias áreas de interesse, promovendo a inovação e o desenvolvimento de novas linhas de pesquisa.

# %% [markdown]
# Em resumo, uma aula de pangenômica tem como objetivo fornecer aos alunos uma compreensão abrangente dos princípios, métodos e aplicações da análise de pangenomas, capacitando-os a realizar pesquisas e contribuir para avanços na área da genômica comparativa e evolutiva.

# %% [markdown]
# ## Introdução

# %% [markdown]
# **Genômica estrutural / funcional**
# * A `genômica estrutural` estudo a organização e estrutura dos genes;
# * A genômica funcional utiliza dados produzidos pelas análises genômicas para descrever funções e interações dos genes e das proteínas;
#
# >O foco da genômica é compreender as funções do DNA através dos genes, da transcrição, da tradução, e das interações proteína-proteína.

# %% [markdown]
# Comparação:
# Enfoque: A genômica estrutural foca na organização física do genoma, enquanto a genômica funcional se concentra nas funções biológicas dos genes.
#
# Metodologia: As técnicas utilizadas na genômica estrutural geralmente envolvem análises de DNA, enquanto na genômica funcional, são usadas técnicas para investigar a expressão e regulação gênica.
#
# Aplicações: Enquanto a genômica estrutural tem aplicações predominantes em diagnóstico clínico e estudos de doenças genéticas, a genômica funcional tem aplicações mais amplas em biologia molecular e pesquisa básica.

# %% [markdown]
# O pangenoma consiste no conjunto total de genes presentes nos genomas de organismos pertencentes a uma mesma espécie ou grupo taxonômico. Esse conjunto é composto pelo core e pelo acessório, existem outra denominaçõe que realacionam a presença do gene e a frequência dentro do popset, exemplos: cloud, shell, soft core e core. O  core engloba os genes compartilhados por todos os genomas, descrevendo as bases fundamentais da biologia do grupo taxonômico em questão, relacionando-se diretamente com suas características fisiológicas e fenotípicas essenciais. Por outro lado, o acessório, também conhecido como dispensável, representa os genes presentes em apenas alguns dos genomas analisados. Esses genes representam a diversidade dentro do grupo estudado, estando associados às adaptações específicas aos diferentes ambientes ocupados pelos organismos.

# %% [markdown]
# Conceitos Fundamentais
# Explique os conceitos básicos relacionados ao tópico.
# Exemplos Práticos
# Forneça exemplos de código para ilustrar os conceitos discutidos.
# Exercícios
# Proponha exercícios para os alunos praticarem os conceitos aprendidos.

# %% [markdown]
# Esta aula abordará os seguintes temas:
#
# * Obter e salvar dados brutos de sequenciamento
# * Instalar softwares e preparar ambiente no Colab (conda/mamba)
# * Controle de qualidade do sequenciamento (análise e trimagem)
# * Alinhamento contra um genoma de referência, visualização e métricas
# * Identificação de SNVs (polimorfismos/indels) e geração de consenso
# * Classificação dos genomas em linhagens de SARS-CoV2
# * Análise da qualidade dos consensos de SARS-CoV2
#
# Use Ctrl+Enter para executar o conteúdo de uma 'célula' de código
#
# Use Shift+Enter para executar código selecionado pelo mouse

# %% [markdown]
# Revisar o fluxo de trabalho da análise

# %% [markdown]
# `

# %% [markdown]
# # Baixando/importando dados

# %% [markdown]
# ## Referências
